# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import svm

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
cols = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Class']
data = pd.read_csv("/content/drive/MyDrive/Wise ML/pima-indians-diabetes.csv", names=cols)
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Class
# 0            6      148             72  ...                     0.627   50      1
# 1            1       85             66  ...                     0.351   31      0
# 2            8      183             64  ...                     0.672   32      1
# 3            1       89             66  ...                     0.167   21      0
# 4            0      137             40  ...                     2.288   33      1
#
# [5 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Class                     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data['Class'].unique()
# Out:
# array([1, 0])

# %%
plt.figure(figsize=(20, 20))
sns.pairplot(data, hue='Class')
plt.show()
plt.close()

# %%
features = data.drop(['Class'], axis=1)
target = data['Class']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.35, random_state=42)

# %% [markdown]
# **Logistic Regression**

# %%
logreg_model = LogisticRegression(max_iter=800, solver='lbfgs')
logreg_model.fit(X_train, y_train)

train_pred = logreg_model.predict(X_train)
test_pred =  logreg_model.predict(X_test)

# %%
print(f"Training Accuracy: {accuracy_score(y_train, train_pred)*100:.3f}%")
print(f"Testing Accuracy: {accuracy_score(y_test, test_pred)*100:.3f}%")
# Out:
# Training Accuracy: 78.156%
# Testing Accuracy: 73.978%

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# **K-Nearest Neighbors**

# %%
k_range = range(1, 21)
train_acc = []
test_acc = []

for k in k_range:    
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train, y_train)

    train_pred = knn_model.predict(X_train)
    test_pred =  knn_model.predict(X_test)

    train_acc.append(accuracy_score(y_train, train_pred))
    test_acc.append(accuracy_score(y_test, test_pred))

# %%
plt.figure(figsize=(10, 5))
plt.plot(k_range, train_acc, label='Train acc.')
plt.plot(k_range, test_acc, label='Test acc.')
plt.legend()
plt.xlabel('k - range')
plt.ylabel('Accuracy')
plt.title('Train acc. vs Test acc.')
plt.show()

# %%
knn_model = KNeighborsClassifier(n_neighbors=6)
knn_model.fit(X_train, y_train)

train_pred = knn_model.predict(X_train)
test_pred =  knn_model.predict(X_test)

print(f"Training Accuracy: {accuracy_score(y_train, train_pred)*100:.3f}%")
print(f"Testing Accuracy: {accuracy_score(y_test, test_pred)*100:.3f}%")
# Out:
# Training Accuracy: 79.359%
# Testing Accuracy: 71.375%

# %% [markdown]
# **DECISION TREES:**

# %% [markdown]
# **CART DT**

# %%
dt_model = DecisionTreeClassifier(criterion='gini', max_depth=10, random_state=42)
dt_model.fit(X_train, y_train)

train_pred = dt_model.predict(X_train)
test_pred =  dt_model.predict(X_test)

print(f"Training Accuracy: {accuracy_score(y_train, train_pred)*100:.3f}%")
print(f"Testing Accuracy: {accuracy_score(y_test, test_pred)*100:.3f}%")
# Out:
# Training Accuracy: 97.996%
# Testing Accuracy: 71.004%

# %%
fig = plt.figure(figsize=(100, 20))
plot_tree(dt_model, filled=True, feature_names=features.columns, class_names=str(data['Class'].unique()))
plt.show()

# %% [markdown]
# **ID3 DT**

# %%
dt_model = DecisionTreeClassifier(criterion='entropy', max_depth=10, random_state=42)
dt_model.fit(X_train, y_train)

train_pred = dt_model.predict(X_train)
test_pred =  dt_model.predict(X_test)

print(f"Training Accuracy: {accuracy_score(y_train, train_pred)*100:.3f}%")
print(f"Testing Accuracy: {accuracy_score(y_test, test_pred)*100:.3f}%")
# Out:
# Training Accuracy: 97.395%
# Testing Accuracy: 75.093%

# %%
fig = plt.figure(figsize=(50, 20))
plot_tree(dt_model, filled=True, feature_names=features.columns, class_names=str(data['Class'].unique()))
plt.show()

# %%
dt_model = DecisionTreeClassifier(criterion='entropy', splitter='random', max_features="sqrt", max_depth=10, random_state=42)
dt_model.fit(X_train, y_train)

train_pred = dt_model.predict(X_train)
test_pred =  dt_model.predict(X_test)

print(f"Training Accuracy: {accuracy_score(y_train, train_pred)*100:.3f}%")
print(f"Testing Accuracy: {accuracy_score(y_test, test_pred)*100:.3f}%")
# Out:
# Training Accuracy: 85.571%
# Testing Accuracy: 68.401%

# %%
fig = plt.figure(figsize=(50, 20))
plot_tree(dt_model, filled=True, feature_names=features.columns, class_names=str(data['Class'].unique()))
plt.show()

# %% [markdown]
# **SVM**

# %%
data['Class'].unique()
# Out:
# array([1, 0])

# %%
def plot_bar(data, cols):
    fig = plt.figure(figsize=(20, 36))
    for loc, col in enumerate(cols):
        plt.subplot(6, 2, loc+1)
        sns.barplot(x='Class', y=col, data=data)
plot_bar(data, data.columns[:-1])
plt.show()

# %%
arr = data.values
arr
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
features = data.drop(['Class'], axis=1)
target = data['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=0)
X_train.shape
# Out:
# (614, 8)

# %%
data.isnull().values.any()
# Out:
# False

# %%
zero_not_allowed = ["Glucose","BloodPressure","SkinThickness"]

for column in zero_not_allowed:
    data[column] = data[column].replace(0, np.NaN)
    mean = int(data[column].mean(skipna = True))
    data[column] = data[column].replace(np.NaN, mean)

# %%
x = data.iloc[:, :-2]
y = data.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size = 0.2)

# %%
clf = svm.SVC(kernel='rbf')
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7922077922077922

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[98,  9],
#        [23, 24]])

# %% [markdown]
# **Performance Metrics:**

# %% [markdown]
# **Classification Accuracy:**

# %%
X = arr[:, 0:8]
y = arr[:, 8]

k_fold = KFold(n_splits=10, random_state=42, shuffle=True)
model = LogisticRegression(max_iter=500)

results = cross_val_score(model, X, y, cv=k_fold, scoring='accuracy')

# %% [markdown]
# **Log Loss:**

# %%
results = cross_val_score(model, X, y, cv=k_fold, scoring='neg_log_loss')

# %%
results.mean()
# Out:
# -0.4888697212994705

# %% [markdown]
# **AUC Score:**

# %%
results = cross_val_score(model, X, y, cv=k_fold, scoring='roc_auc')

# %%
results.mean()
# Out:
# 0.8285983552660445

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=700, shuffle=True)

# %%
model = LogisticRegression(max_iter=500)
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[131,  23],
#        [ 30,  47]])

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.85      0.83       154
#          1.0       0.67      0.61      0.64        77
#
#     accuracy                           0.77       231
#    macro avg       0.74      0.73      0.74       231
# weighted avg       0.77      0.77      0.77       231

# %%
roc_auc_score(y_test, pred)
# Out:
# 0.7305194805194806

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred)

# %%
fpr
# Out:
# array([0.        , 0.14935065, 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.61038961, 1.        ])

# %%
plt.plot(fpr, tpr)
plt.title('ROC - AUC Curve')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()

# %% [markdown]
# **PCA**

# %%
featurenames = ['Pregnancies', 'Glucose',	'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',	'DiabetesPedigreeFunction', 'Age']
# separating features
features = data.loc[:,featurenames]

# separating target
labels = data.loc[:,'Class']

# %%
features = StandardScaler().fit_transform(features)

# %%
print(features)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
import numpy as np
pca = PCA(n_components=2)

pct = pca.fit_transform(features)

print(np.cumsum(pca.explained_variance_ratio_))
principal_df = pd.DataFrame(pct,columns=['pc1','pc2'])
display(principal_df)
finaldf = pd.concat([principal_df,labels],axis=1)
# Out:
# [0.26179749 0.47819876]
#           pc1       pc2
# 0    1.068503  1.234895
# 1   -1.121683 -0.733852
# 2   -0.396477  1.595876
# 3   -1.115781 -1.271241
# 4    2.359334 -2.184819
# ..        ...       ...
# 763  1.562085  1.923150
# 764 -0.100405 -0.614181
# 765 -0.283475  0.097065
# 766 -1.060324  0.837062
# 767 -0.839892 -1.151755
#
# [768 rows x 2 columns]

# %%
print(principal_df)
# Out:
#           pc1       pc2
# 0    1.068503  1.234895
# 1   -1.121683 -0.733852
# 2   -0.396477  1.595876
# 3   -1.115781 -1.271241
# 4    2.359334 -2.184819
# ..        ...       ...
# 763  1.562085  1.923150
# 764 -0.100405 -0.614181
# 765 -0.283475  0.097065
# 766 -1.060324  0.837062
# 767 -0.839892 -1.151755
#
# [768 rows x 2 columns]

# %%
display(finaldf)
# Out:
#           pc1       pc2   Class
# 0    1.068503  1.234895  zeroes
# 1   -1.121683 -0.733852     NaN
# 2   -0.396477  1.595876  zeroes
# 3   -1.115781 -1.271241     NaN
# 4    2.359334 -2.184819     NaN
# ..        ...       ...     ...
# 763  1.562085  1.923150     NaN
# 764 -0.100405 -0.614181    ones
# 765 -0.283475  0.097065  zeroes
# 766 -1.060324  0.837062     NaN
# 767 -0.839892 -1.151755     NaN
#
# [768 rows x 3 columns]

# %%
import seaborn as sns

plt.figure(figsize=(8,8))
sns.scatterplot('pc1', 'pc2', hue='Class', data=finaldf, s=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['ones', 	'zeroes']
colors = ['g', 'y']
for target, color in zip(targets,colors):
    indicesToKeep = labels == target
    ax.scatter(finaldf.loc[indicesToKeep, 'pc1']
               , finaldf.loc[indicesToKeep, 'pc2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# **Artificial Neural Network**

# %%
train_df, test_df, train_df['Class'], test_df['Class'] = train_test_split(data.drop(['Class'], axis=1), data['Class'], test_size=0.2, random_state=0, shuffle=True)
train_df.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Class
# 603            7    150.0           78.0  ...                     0.692   54      1
# 118            4     97.0           60.0  ...                     0.443   22      0
# 247            0    165.0           90.0  ...                     0.427   23      0
# 157            1    109.0           56.0  ...                     0.833   23      0
# 468            8    120.0           72.0  ...                     0.183   38      1
#
# [5 rows x 9 columns]

# %%
predictors = train_df.columns[:-1]
target = 'Class'

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train = scaler.fit_transform(train_df)
scaled_train
# Out:
# array([[0.41176471, 0.68831169, 0.55102041, ..., 0.26216909, 0.55      ,
#         1.        ],
#        [0.23529412, 0.34415584, 0.36734694, ..., 0.1558497 , 0.01666667,
#         0.        ],
#        [0.        , 0.78571429, 0.67346939, ..., 0.14901793, 0.03333333,
#         0.        ],
#        ...,
#        [0.23529412, 0.32467532, 0.41836735, ..., 0.02988898, 0.        ,
#         0.        ],
#        [0.64705882, 0.26623377, 0.51020408, ..., 0.09479078, 0.23333333,
#         0.        ],
#        [0.29411765, 0.5974026 , 0.59183673, ..., 0.23996584, 0.8       ,
#         0.        ]])

# %%
scaled_train_df = pd.DataFrame(scaled_train, columns=train_df.columns.values)
scaled_train_df
# Out:
#      Pregnancies   Glucose  ...       Age  Class
# 0       0.411765  0.688312  ...  0.550000    1.0
# 1       0.235294  0.344156  ...  0.016667    0.0
# 2       0.000000  0.785714  ...  0.033333    0.0
# 3       0.058824  0.422078  ...  0.033333    0.0
# 4       0.470588  0.493506  ...  0.283333    1.0
# ..           ...       ...  ...       ...    ...
# 609     0.588235  0.370130  ...  0.700000    0.0
# 610     0.411765  0.746753  ...  0.250000    1.0
# 611     0.235294  0.324675  ...  0.000000    0.0
# 612     0.647059  0.266234  ...  0.233333    0.0
# 613     0.294118  0.597403  ...  0.800000    0.0
#
# [614 rows x 9 columns]

# %% [markdown]
# **Model Building:**

# %%
# Sequential Layer
model = Sequential()

# %%
# Hidden layers
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=50, activation='relu'))

# %%
# Output Layer
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
X = scaled_train_df.drop(target, axis=1).values
y = scaled_train_df[[target]].values

# %%
# Train the model

model.fit(
    x=X,
    y=y,
    epochs=100,
    shuffle=True,
    verbose=2,
)
# Out:
# Epoch 1/100
# 20/20 - 1s - loss: 0.2421
# Epoch 2/100
# 20/20 - 0s - loss: 0.1888
# Epoch 3/100
# 20/20 - 0s - loss: 0.1782
# Epoch 4/100
# 20/20 - 0s - loss: 0.1717
# Epoch 5/100
# 20/20 - 0s - loss: 0.1674
# Epoch 6/100
# 20/20 - 0s - loss: 0.1612
# Epoch 7/100
# 20/20 - 0s - loss: 0.1547
# Epoch 8/100
# 20/20 - 0s - loss: 0.1548
# Epoch 9/100
# 20/20 - 0s - loss: 0.1531
# Epoch 10/100
# 20/20 - 0s - loss: 0.1508
# Epoch 11/100
# 20/20 - 0s - loss: 0.1518
# Epoch 12/100
# 20/20 - 0s - loss: 0.1486
# Epoch 13/100
# 20/20 - 0s - loss: 0.1464
# Epoch 14/100
# 20/20 - 0s - loss: 0.1478
# Epoch 15/100
# 20/20 - 0s - loss: 0.1458
# Epoch 16/100
# 20/20 - 0s - loss: 0.1418
# Epoch 17/100
# 20/20 - 0s - loss: 0.1467
# Epoch 18/100
# 20/20 - 0s - loss: 0.1430
# Epoch 19/100
# 20/20 - 0s - loss: 0.1464
# Epoch 20/100
# 20/20 - 0s - loss: 0.1459
# Epoch 21/100
# 20/20 - 0s - loss: 0.1470
# Epoch 22/100
# 20/20 - 0s - loss: 0.1429
# Epoch 23/100
# 20/20 - 0s - loss: 0.1468
# Epoch 24/100
# 20/20 - 0s - loss: 0.1391
# Epoch 25/100
# 20/20 - 0s - loss: 0.1360
# Epoch 26/100
# 20/20 - 0s - loss: 0.1354
# Epoch 27/100
# 20/20 - 0s - loss: 0.1399
# Epoch 28/100
# 20/20 - 0s - loss: 0.1358
# Epoch 29/100
# 20/20 - 0s - loss: 0.1379
# Epoch 30/100
# 20/20 - 0s - loss: 0.1360
# Epoch 31/100
# 20/20 - 0s - loss: 0.1396
# Epoch 32/100
# 20/20 - 0s - loss: 0.1381
# Epoch 33/100
# 20/20 - 0s - loss: 0.1383
# Epoch 34/100
# 20/20 - 0s - loss: 0.1332
# Epoch 35/100
# 20/20 - 0s - loss: 0.1311
# Epoch 36/100
# 20/20 - 0s - loss: 0.1326
# Epoch 37/100
# 20/20 - 0s - loss: 0.1351
# Epoch 38/100
# 20/20 - 0s - loss: 0.1385
# Epoch 39/100
# 20/20 - 0s - loss: 0.1333
# Epoch 40/100
# 20/20 - 0s - loss: 0.1302
# Epoch 41/100
# 20/20 - 0s - loss: 0.1325
# Epoch 42/100
# 20/20 - 0s - loss: 0.1303
# Epoch 43/100
# 20/20 - 0s - loss: 0.1292
# Epoch 44/100
# 20/20 - 0s - loss: 0.1270
# Epoch 45/100
# 20/20 - 0s - loss: 0.1359
# Epoch 46/100
# 20/20 - 0s - loss: 0.1272
# Epoch 47/100
# 20/20 - 0s - loss: 0.1249
# Epoch 48/100
# 20/20 - 0s - loss: 0.1254
# Epoch 49/100
# 20/20 - 0s - loss: 0.1235
# Epoch 50/100
# 20/20 - 0s - loss: 0.1225
# Epoch 51/100
# 20/20 - 0s - loss: 0.1245
# Epoch 52/100
# 20/20 - 0s - loss: 0.1210
# Epoch 53/100
# 20/20 - 0s - loss: 0.1225
# Epoch 54/100
# 20/20 - 0s - loss: 0.1196
# Epoch 55/100
# 20/20 - 0s - loss: 0.1195
# Epoch 56/100
# 20/20 - 0s - loss: 0.1183
# Epoch 57/100
# 20/20 - 0s - loss: 0.1188
# Epoch 58/100
# 20/20 - 0s - loss: 0.1179
# Epoch 59/100
# 20/20 - 0s - loss: 0.1257
# Epoch 60/100
# 20/20 - 0s - loss: 0.1260
# Epoch 61/100
# 20/20 - 0s - loss: 0.1180
# Epoch 62/100
# 20/20 - 0s - loss: 0.1142
# Epoch 63/100
# 20/20 - 0s - loss: 0.1183
# Epoch 64/100
# 20/20 - 0s - loss: 0.1139
# Epoch 65/100
# 20/20 - 0s - loss: 0.1119
# Epoch 66/100
# 20/20 - 0s - loss: 0.1126
# Epoch 67/100
# 20/20 - 0s - loss: 0.1099
# Epoch 68/100
# 20/20 - 0s - loss: 0.1105
# Epoch 69/100
# 20/20 - 0s - loss: 0.1099
# Epoch 70/100
# 20/20 - 0s - loss: 0.1116
# Epoch 71/100
# 20/20 - 0s - loss: 0.1098
# Epoch 72/100
# 20/20 - 0s - loss: 0.1111
# Epoch 73/100
# 20/20 - 0s - loss: 0.1123
# Epoch 74/100
# 20/20 - 0s - loss: 0.1144
# Epoch 75/100
# 20/20 - 0s - loss: 0.1063
# Epoch 76/100
# 20/20 - 0s - loss: 0.1088
# Epoch 77/100
# 20/20 - 0s - loss: 0.1069
# Epoch 78/100
# 20/20 - 0s - loss: 0.1092
# Epoch 79/100
# 20/20 - 0s - loss: 0.1133
# Epoch 80/100
# 20/20 - 0s - loss: 0.1064
# Epoch 81/100
# 20/20 - 0s - loss: 0.1040
# Epoch 82/100
# 20/20 - 0s - loss: 0.1041
# Epoch 83/100
# 20/20 - 0s - loss: 0.1010
# Epoch 84/100
# 20/20 - 0s - loss: 0.1037
# Epoch 85/100
# 20/20 - 0s - loss: 0.1022
# Epoch 86/100
# 20/20 - 0s - loss: 0.1020
# Epoch 87/100
# 20/20 - 0s - loss: 0.1073
# Epoch 88/100
# 20/20 - 0s - loss: 0.1102
# Epoch 89/100
# 20/20 - 0s - loss: 0.1036
# Epoch 90/100
# 20/20 - 0s - loss: 0.0997
# Epoch 91/100
# 20/20 - 0s - loss: 0.0958
# Epoch 92/100
# 20/20 - 0s - loss: 0.0996
# Epoch 93/100
# 20/20 - 0s - loss: 0.0993
# Epoch 94/100
# 20/20 - 0s - loss: 0.0960
# Epoch 95/100
# 20/20 - 0s - loss: 0.0997
# Epoch 96/100
# 20/20 - 0s - loss: 0.0953
# Epoch 97/100
# 20/20 - 0s - loss: 0.0968
# Epoch 98/100
# 20/20 - 0s - loss: 0.0990
# Epoch 99/100
# 20/20 - 0s - loss: 0.0945
# Epoch 100/100
# 20/20 - 0s - loss: 0.0935

# %%
def scaler_inverse_transform(value):
    scaled_prediction = value
    scaled_prediction -= added_factor
    return scaled_prediction / multiply_factor

# %%
multiply_factor = scaler.scale_[8]
added_factor = scaler.min_[8]

# %%
scaler_inverse_transform(y[:1][0][0])
# Out:
# 1.0

# %%
prediction = model.predict(X[:])
prediction
# Out:
# array([[ 6.77064955e-01],
#        [ 6.39144182e-02],
#        [ 1.81830242e-01],
#        [ 1.01695471e-01],
#        [ 5.17170727e-01],
#        [ 1.06553364e+00],
#        [ 6.48977160e-01],
#        [ 8.34043026e-01],
#        [ 2.97162738e-02],
#        [ 1.18101783e-01],
#        [ 7.07769573e-01],
#        [ 3.39502603e-01],
#        [ 1.25556901e-01],
#        [ 7.42278844e-02],
#        [ 2.54197896e-01],
#        [ 4.94395271e-02],
#        [ 1.39838252e-02],
#        [ 5.02558127e-02],
#        [ 4.80333060e-01],
#        [ 6.28926039e-01],
#        [ 4.37406451e-01],
#        [ 1.81840546e-03],
#        [ 6.89790994e-02],
#        [ 1.61416665e-01],
#        [ 4.42445815e-01],
#        [-9.68883745e-03],
#        [ 3.01842034e-01],
#        [ 2.09857628e-01],
#        [ 2.02875108e-01],
#        [ 1.23233110e-01],
#        [-1.24025807e-01],
#        [ 2.94291321e-02],
#        [ 8.80906343e-01],
#        [ 8.68657291e-01],
#        [ 5.59397116e-02],
#        [ 1.36779219e-01],
#        [ 1.48903579e-01],
#        [ 9.69464779e-01],
#        [ 3.85957181e-01],
#        [ 1.00692391e+00],
#        [-6.70862943e-02],
#        [-2.17418559e-03],
#        [-2.31474891e-01],
#        [ 1.82384968e-01],
#        [ 8.60001028e-01],
#        [ 1.26177639e-01],
#        [ 6.38357520e-01],
#        [ 1.60635442e-01],
#        [ 6.85880557e-02],
#        [ 4.66836616e-02],
#        [-9.18416455e-02],
#        [ 3.97466272e-02],
#        [ 5.78124523e-01],
#        [ 7.49200583e-02],
#        [ 1.25154927e-01],
#        [ 1.37872964e-01],
#        [ 7.38618612e-01],
#        [ 7.57559776e-01],
#        [ 7.85527170e-01],
#        [ 2.87322730e-01],
#        [ 1.01998873e-01],
#        [ 2.15562358e-01],
#        [ 7.81997144e-01],
#        [ 9.83665168e-01],
#        [ 2.37787534e-02],
#        [ 2.46575966e-01],
#        [ 9.13087010e-01],
#        [-2.84932833e-02],
#        [ 7.03936890e-02],
#        [ 1.95387639e-02],
#        [ 2.48631895e-01],
#        [-1.44193415e-02],
#        [ 9.01775599e-01],
#        [-5.65110147e-03],
#        [-1.47746410e-02],
#        [ 3.69487792e-01],
#        [ 2.70559520e-01],
#        [-6.01370558e-02],
#        [ 7.24007666e-01],
#        [-8.17081146e-03],
#        [ 3.91184211e-01],
#        [ 9.29278791e-01],
#        [ 1.19282508e+00],
#        [ 8.34359154e-02],
#        [-2.49990206e-02],
#        [ 7.35138714e-01],
#        [ 8.97580683e-02],
#        [ 1.83031544e-01],
#        [-1.36500850e-01]], dtype=float32)

# %%
for idx in range(404):    
    print(f"Actual Price: {scaler_inverse_transform(y[idx][0])* 1000:.2f}$")
    print(f"Predicted Price: {scaler_inverse_transform(prediction[idx][0])* 1000:.2f}$")
    print("-"*30)
# Out:
# Actual Price: 1000.00$
# Predicted Price: 677.06$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 63.91$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 181.83$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 101.70$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 517.17$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1065.53$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 648.98$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 834.04$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 29.72$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 118.10$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 707.77$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 339.50$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 125.56$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 74.23$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 254.20$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 49.44$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 13.98$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 50.26$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 480.33$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 628.93$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 437.41$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 1.82$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 108.03$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -102.40$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 139.96$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 53.15$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 271.99$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 666.85$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 111.74$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 959.61$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 718.99$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -48.86$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 667.50$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 462.73$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 628.80$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 108.00$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 258.94$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 9.90$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 47.28$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 269.78$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 34.17$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 947.74$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 840.46$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 265.73$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 38.66$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 145.42$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -31.79$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 76.52$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 144.10$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 197.78$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 270.61$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 74.61$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 153.87$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 212.35$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 615.07$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -29.42$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 295.80$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 48.85$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -91.39$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 155.42$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -23.79$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -42.24$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 803.49$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 436.37$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -84.50$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 125.09$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 263.51$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 5.45$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 727.07$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 675.77$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 437.58$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 688.60$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 663.26$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 456.55$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -18.13$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 300.75$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 298.82$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 482.84$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -22.58$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 363.94$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 587.11$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 893.01$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 126.95$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 929.03$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 347.60$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1054.59$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 110.13$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 441.08$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 59.16$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 550.18$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -24.86$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 725.20$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -29.07$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 108.33$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 69.94$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 165.61$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 245.02$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 339.40$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 52.82$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 884.13$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 282.81$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1162.96$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 432.68$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 334.22$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 151.32$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 422.13$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 149.04$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -57.97$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 296.10$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 26.75$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 997.05$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 34.23$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 396.93$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 917.51$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 368.38$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 288.32$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 32.95$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -19.87$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 93.91$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 72.77$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 381.25$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 420.02$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -19.83$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 348.25$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 68.49$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 46.84$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 824.89$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 772.88$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 256.16$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 163.41$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 340.73$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 98.24$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 2.28$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 191.46$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 61.55$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 861.85$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 961.69$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 362.95$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 289.37$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 701.80$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -22.22$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1052.34$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 869.29$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -34.77$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 120.64$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 192.88$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 125.09$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 626.97$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 123.10$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -38.40$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 844.42$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 785.65$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 721.95$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 361.63$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 423.06$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 29.90$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 666.70$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 171.90$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 8.05$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -83.87$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 247.96$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -26.55$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 174.37$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 598.43$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 107.11$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 791.44$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 555.04$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 235.81$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -29.69$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1056.90$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 159.75$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 444.36$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 347.23$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 14.84$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 8.45$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 819.87$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 974.30$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 805.56$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 575.44$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 108.20$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 74.14$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -13.12$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 154.14$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -2.72$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 979.83$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 166.40$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 565.05$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 392.82$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 274.09$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 771.37$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1140.13$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 128.56$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 504.86$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 169.03$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 975.35$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 989.31$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 894.90$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 922.49$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 71.96$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 560.57$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 18.19$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 831.34$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 626.09$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -73.23$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 333.81$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 65.83$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 878.63$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 104.02$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 81.47$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 240.77$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 893.36$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 270.21$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 849.47$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 764.23$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 171.81$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 972.22$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 352.66$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 84.70$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 28.62$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 395.11$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 195.37$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1006.03$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 596.35$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 32.35$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 7.93$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1086.82$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 832.39$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -26.40$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 107.18$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 198.22$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 483.62$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 174.65$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 647.45$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 309.23$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 947.71$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -46.21$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 78.29$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 187.52$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 963.44$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 1.13$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1035.88$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -4.30$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 786.32$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 43.54$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 841.44$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 571.98$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 903.36$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 982.88$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 94.13$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 879.21$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1118.26$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 99.61$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 468.86$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 238.26$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 642.13$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 67.24$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 236.84$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 896.58$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 999.04$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 93.51$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 27.33$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 101.30$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 251.73$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 980.77$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 190.48$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 268.68$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 479.34$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 127.64$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1056.61$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 193.35$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 385.00$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 772.97$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 280.28$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1135.47$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 304.25$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 77.62$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 8.87$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 865.41$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 79.68$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 433.68$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 225.46$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 1.01$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 285.44$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 583.75$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 97.95$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 894.95$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -25.02$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 323.25$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1123.78$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -10.48$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 13.82$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 998.87$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 154.06$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 507.06$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 156.32$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 245.43$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -3.91$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 216.60$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 316.38$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 149.66$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 258.79$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 661.95$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 906.51$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 99.39$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1033.23$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 323.71$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 466.36$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 458.57$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1014.88$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 12.53$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 940.21$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 622.84$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 247.31$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 901.55$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 712.84$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 177.10$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 266.33$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 111.36$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1103.46$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 51.19$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 323.88$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1058.27$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 147.04$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 848.79$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -60.84$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 380.43$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 217.79$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -40.45$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 859.55$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 167.94$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 31.42$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 243.85$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 877.62$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 945.87$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -34.67$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 590.66$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 458.38$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 566.94$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1164.97$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 177.34$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 521.60$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -29.19$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 875.77$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 583.54$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 637.27$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -41.12$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 692.38$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 310.96$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 684.25$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 3.51$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 328.39$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 237.30$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 250.03$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 853.22$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 915.90$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 525.65$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 144.34$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 432.93$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -40.02$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 263.91$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 109.60$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 41.63$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 883.38$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 12.31$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 660.41$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 742.14$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -66.42$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 373.07$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 591.38$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 993.50$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 100.12$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 21.64$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -110.05$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 38.72$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 907.18$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -15.35$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: -160.23$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 134.59$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 203.50$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 783.22$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 114.58$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 628.65$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 41.28$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 213.52$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 71.78$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 23.18$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1042.20$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 557.06$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 88.91$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 326.13$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 309.24$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 31.14$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 42.29$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 70.47$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 1009.50$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 409.94$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 19.44$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 123.96$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 139.22$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 82.74$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 7.71$
# ------------------------------
# Actual Price: 1000.00$
# Predicted Price: 766.79$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 574.91$
# ------------------------------
# Actual Price: 0.00$
# Predicted Price: 347.49$
# ------------------------------

# %% [markdown]
# **Convolutional Neural Network:**

# %% [markdown]
# **Library Declaration:**

# %%
# Importing the Keras libraries and packages
import os
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.preprocessing.image import ImageDataGenerator
